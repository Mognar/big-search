# %%
#This bit imports the necessary code packages to run this program
import json
import requests

# %%
#Replace "Housing" with whichever term you would like to search on. 
#Please make sure the term is in quotes
vloop = "Housing"
#This bit puts the term into a search on data.parliament.uk
slug = "http://eldaddp.azurewebsites.net/terms.json?prefLabel={}".format(vloop)
print(slug)
r=requests.get(slug)
#If this works, the following line should output the full text of the 
#data.parliament.uk page on your term of choice.
print(r.text)
# Out:
# http://eldaddp.azurewebsites.net/terms.json?prefLabel=Housing
# { "format" : "linked-data-api", "version" : "0.2", "result" : {"_about" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Housing", "definition" : "http://eldaddp.azurewebsites.net/meta/terms.json?prefLabel=Housing", "extendedMetadataVersion" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Housing&_metadata=all", "first" : "http://eldaddp.azurewebsites.net/terms.json?_page=0&prefLabel=Housing", "hasPart" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Housing", "isPartOf" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Housing", "items" : [{"_about" : "http://data.parliament.uk/terms/91569", "attribute" : ["SIT", "Subject specialist term", "TPG"], "broader" : {"_about" : "http://data.parliament.uk/terms/351449", "prefLabel" : {"_value" : "Housing and planning"}
#       }
#       , "class" : "SIT", "exactMatch" : [{"_about" : "http://data.parliament.uk/terms/49157", "prefLabel" : {"_value" : "Accommodation"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91567", "prefLabel" : {"_value" : "Houses"}
#       }
#       ], "isPreferred" : {"_value" : "true", "_datatype" : "boolean"}
#       , "narrower" : [{"_about" : "http://data.parliament.uk/terms/351507", "prefLabel" : {"_value" : "Housing standards"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/351509", "prefLabel" : {"_value" : "Housing supply"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/351523", "prefLabel" : {"_value" : "Housing overcrowding"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/431403", "prefLabel" : {"_value" : "Almshouses"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/90115", "prefLabel" : {"_value" : "Letting agents"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/90150", "prefLabel" : {"_value" : "Affordable housing"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91121", "prefLabel" : {"_value" : "Empty property"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91448", "prefLabel" : {"_value" : "Grace and favour housing"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91573", "prefLabel" : {"_value" : "Housing completions"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91574", "prefLabel" : {"_value" : "Housing estates"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91575", "prefLabel" : {"_value" : "Housing improvement"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91576", "prefLabel" : {"_value" : "Housing market"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91577", "prefLabel" : {"_value" : "Housing occupancy"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91578", "prefLabel" : {"_value" : "Housing problems"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91579", "prefLabel" : {"_value" : "Housing starts"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91580", "prefLabel" : {"_value" : "Housing stock"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92077", "prefLabel" : {"_value" : "Mortgages"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92315", "prefLabel" : {"_value" : "Owner occupation"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92810", "prefLabel" : {"_value" : "Rented housing"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92931", "prefLabel" : {"_value" : "Second homes"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/93170", "prefLabel" : {"_value" : "Supported housing"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/93239", "prefLabel" : {"_value" : "Temporary accommodation"}
#       }
#       ], "prefLabel" : {"_value" : "Housing"}
#       , "related" : [{"_about" : "http://data.parliament.uk/terms/90659", "prefLabel" : {"_value" : "Compulsory purchase"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91566", "prefLabel" : {"_value" : "Households"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91571", "prefLabel" : {"_value" : "Housing benefit"}
#       }
#       ]}
#     , {"_about" : "http://data.parliament.uk/terms/95629", "attribute" : "Do not use for concept mapping", "broader" : {"_about" : "http://data.parliament.uk/terms/95631", "prefLabel" : {"_value" : "Housing and planning"}
#       }
#       , "class" : "TPG", "exactMatch" : {"_about" : "http://data.parliament.uk/terms/51631", "prefLabel" : {"_value" : "Squatting"}
#       }
#       , "isPreferred" : {"_value" : "true", "_datatype" : "boolean"}
#       , "narrower" : [{"_about" : "http://data.parliament.uk/terms/95577", "prefLabel" : {"_value" : "Empty property"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95626", "prefLabel" : {"_value" : "Homelessness"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95630", "prefLabel" : {"_value" : "Housing adaptations"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95633", "prefLabel" : {"_value" : "Housing standards"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95634", "prefLabel" : {"_value" : "Housing supply"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95700", "prefLabel" : {"_value" : "Overcrowding"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95702", "prefLabel" : {"_value" : "Owner occupation"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95722", "prefLabel" : {"_value" : "Private rented housing"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95753", "prefLabel" : {"_value" : "Social rented housing"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/95762", "prefLabel" : {"_value" : "Supported housing"}
#       }
#       ], "prefLabel" : {"_value" : "Housing"}
#     }
#     ], "itemsPerPage" : 10, "page" : 0, "startIndex" : 1, "totalResults" : 2, "type" : ["http://purl.org/linked-data/api/vocab#ListEndpoint", "http://purl.org/linked-data/api/vocab#Page"]}
# }

# %%
#This part reads the json code of the term you searched for. 
j=json.loads(r.text)
terminfo = j['result']['items'][0]['_about']

# %%
#This is the part that does the heavy lifting. 
#The code here finds the preferred name and ID number of each term under your
#chosen term. 
#It then looks to see if the child terms of your chosen term have any children. 
#If it does, it pulls out the name and ID of that term too. 
#The term names are all printed below.
rel = []
termjson = terminfo + '.json'
tj = requests.get(termjson)
j2 = json.loads(tj.text)
j3 = j2['result']['primaryTopic']['narrower']
for i in j3:
    print(i['prefLabel']['_value'])
    jsnoos = i['_about']
    jbing = jsnoos.split("/")[4]
    rel.append(jbing)
    j4 = i['_about']
    j5 = j4 + '.json'
    j6 = requests.get(j5)
    j7 = json.loads(j6.text)
    try:
        j8 = j7['result']['primaryTopic']['narrower']
        for i in j8:
            print(i['prefLabel']['_value'])
            ksnoos = i['_about']
            kbing = ksnoos.split("/")[4]
            rel.append(kbing)
            k4 = i['_about']
            k5 = k4 + '.json'
            k6 = requests.get(k5)
            k7 = json.loads(k6.text)
            try:
                k8 = k7['result']['primaryTopic']['narrower']
                for i in k8:
                    print(i['prefLabel']['_value'])
                    lsnoos = i['_about']
                    lbing = lsnoos.split("/")[4]
                    rel.append(lbing)
                    l4 = i['_about']
                    l5 = l4 + '.json'
                    l6 = requests.get(l5)
                    l7 = json.loads(l6.text)
                    try:
                        l8 = l7['result']['primaryTopic']['narrower']
                        for i in l8:
                            print(i['prefLabel']['_value'])
                    except: "KeyError"
                    pass
            except: "KeyError"
            pass
    except: "KeyError"
    pass
# Out:
# Housing standards
# Housing supply
# Housing overcrowding
# Almshouses
# Letting agents
# Affordable housing
# Empty property
# Grace and favour housing
# Housing completions
# Housing estates
# Housing improvement
# Insulation
# Urea formaldehyde foam
# Double glazing
# Slum clearance
# Housing market
# Housing occupancy
# Housing problems
# Homelessness
# Slums
# Squatting
# Housing starts
# Housing stock
# Mortgages
# Owner occupation
# First time buyers
# Freehold
# Leasehold
# Mobile homes
# Mortgages
# Second homes
# Shared ownership
# Rented housing
# Assured tenancies
# Evictions
# Landlord and tenant
# Landlords
# Repossession orders
# Security of tenure
# Tenancy agreements
# Tolerated trespassers
# Assured tenancies
# Protected tenancies
# Secure tenancies
# Shorthold tenancies
# Tied housing
# Tenants
# Tenants' choice
# Tenants' rights
# Private rented housing
# Leaseback arrangements
# Service charges
# Shared housing
# Rents
# Social rented housing
# Council housing
# Housing associations
# Housing companies
# Housing trusts
# Second homes
# Supported housing
# Temporary accommodation
# Night shelters
# Accommodation centres
# Bed and breakfast accommodation
# Holiday accommodation
# Hostels
# Hotels
# Refuges
# Resettlement units
# subject_ses:(351507 OR 351509 OR 351523 OR 431403 OR 90115 OR 90150 OR 91121 OR 91448 OR 91573 OR 91574 OR 91575 OR 91686 OR 13552 OR 289208 OR 93032 OR 91576 OR 91577 OR 91578 OR 91540 OR 93033 OR 93097 OR 91579 OR 91580 OR 92077 OR 92315 OR 91282 OR 91366 OR 91809 OR 92058 OR 92077 OR 92931 OR 92989 OR 92810 OR 90270 OR 91178 OR 91789 OR 91790 OR 92819 OR 92949 OR 93243 OR 93244 OR 93245 OR 93246 OR 92597 OR 11278 OR 92972 OR 92988 OR 92811 OR 93053 OR 90740 OR 91570 OR 91572 OR 91582 OR 92931 OR 93170 OR 93239 OR 432423 OR 90116 OR 90320 OR 91532 OR 91556 OR 91557 OR 92774 OR 92833) session:17/19

# %%
#This part takes all of the IDs and puts them into a text string, with "OR" 
#in between each ID. This will output a text string that can be copied into 
#Parliamentary Search. 
#
#You can change the paramters of the search below, or change them in Search.
stringy = ' OR '.join(rel)
print('subject_ses:('+stringy+") session:17/19")
