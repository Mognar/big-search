# %%
#This bit imports the necessary code packages to run this program
import json
import requests

# %%
#Replace "Housing" with whichever term you would like to search on. 
#Please make sure the term is in quotes
#If you would like Topic terms left out, leave ExcludeTopicTerms as 1, if you want to look for them, set this to 0.
TermToSearch = "Members"
ExcludeTopicTerms = 0

# %% [markdown]
# **Once you've changed the term in the box above, go to the top of the page and Click *Cell > Run All*. This will run the program and produce your search string at the end of the page.**

# %%
#This bit puts the term into a search on data.parliament.uk
if ExcludeTopicTerms == 1:
    slug = "http://eldaddp.azurewebsites.net/terms.json?prefLabel={}&maxEx-attribute=TPG".format(TermToSearch)
else:
    slug = "http://eldaddp.azurewebsites.net/terms.json?prefLabel={}".format(TermToSearch)
print(slug)
r=requests.get(slug)
#If this works, the following line should output the full text of the 
#data.parliament.uk page on your term of choice.
print(r.text)
# Out:
# http://eldaddp.azurewebsites.net/terms.json?prefLabel=Members
# { "format" : "linked-data-api", "version" : "0.2", "result" : {"_about" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Members", "definition" : "http://eldaddp.azurewebsites.net/meta/terms.json?prefLabel=Members", "extendedMetadataVersion" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Members&_metadata=all", "first" : "http://eldaddp.azurewebsites.net/terms.json?_page=0&prefLabel=Members", "hasPart" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Members", "isPartOf" : "http://eldaddp.azurewebsites.net/terms.json?prefLabel=Members", "items" : [{"_about" : "http://data.parliament.uk/terms/51550", "attribute" : "TPG", "class" : "", "exactMatch" : {"_about" : "http://data.parliament.uk/terms/95674", "prefLabel" : {"_value" : "Members of Parliament"}
#       }
#       , "isPreferred" : {"_value" : "false", "_datatype" : "boolean"}
#       , "prefLabel" : {"_value" : "Members"}
#     }
#     , {"_about" : "http://data.parliament.uk/terms/91976", "attribute" : ["SIT", "Subject specialist term", "TPG"], "broader" : [{"_about" : "http://data.parliament.uk/terms/61054", "prefLabel" : {"_value" : "Parliament"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92499", "prefLabel" : {"_value" : "Politicians"}
#       }
#       ], "class" : "SIT", "isPreferred" : {"_value" : "true", "_datatype" : "boolean"}
#       , "narrower" : [{"_about" : "http://data.parliament.uk/terms/90187", "prefLabel" : {"_value" : "All party groups"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/90297", "prefLabel" : {"_value" : "Backbenchers"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/90715", "prefLabel" : {"_value" : "Convener"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/90990", "prefLabel" : {"_value" : "Dual mandate"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91239", "prefLabel" : {"_value" : "Father of the House"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91338", "prefLabel" : {"_value" : "Former members"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91560", "prefLabel" : {"_value" : "House of Commons composition"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91630", "prefLabel" : {"_value" : "Independent members"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91979", "prefLabel" : {"_value" : "Members' constituency work"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91980", "prefLabel" : {"_value" : "Members' interests"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91981", "prefLabel" : {"_value" : "Members' partners"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91982", "prefLabel" : {"_value" : "Members' staff"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91983", "prefLabel" : {"_value" : "Members' suspension"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91984", "prefLabel" : {"_value" : "Members' workload"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92040", "prefLabel" : {"_value" : "Ministers"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92147", "prefLabel" : {"_value" : "New members"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92162", "prefLabel" : {"_value" : "NNIA Initial Presiding Officer"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92254", "prefLabel" : {"_value" : "Oldest member"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92348", "prefLabel" : {"_value" : "Parliamentary private secretaries"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92785", "prefLabel" : {"_value" : "Regional members"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/93079", "prefLabel" : {"_value" : "Speaker's deputies"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/93494", "prefLabel" : {"_value" : "Whips"}
#       }
#       ], "prefLabel" : {"_value" : "Members"}
#       , "related" : [{"_about" : "http://data.parliament.uk/terms/90689", "prefLabel" : {"_value" : "Constituencies"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/91171", "prefLabel" : {"_value" : "European Parliament members"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92212", "prefLabel" : {"_value" : "Oaths and affirmations"}
#       }
#       , {"_about" : "http://data.parliament.uk/terms/92826", "prefLabel" : {"_value" : "Research assistants"}
#       }
#       ]}
#     ], "itemsPerPage" : 10, "page" : 0, "startIndex" : 1, "totalResults" : 2, "type" : ["http://purl.org/linked-data/api/vocab#ListEndpoint", "http://purl.org/linked-data/api/vocab#Page"]}
# }

# %%
#This part reads the json code of the term you searched for. 
j=json.loads(r.text)
if j['result']['totalResults'] == 0:
    print('No terms found, please try another term')
else:
    if j['result']['items'][0]['isPreferred']['_value'] == "false":
        terminfo = j['result']['items'][0]['exactMatch']['_about']
    else:
        terminfo = j['result']['items'][0]['_about']
    termname = j['result']['items'][0]['prefLabel']['_value']

# %%
#This is the part that does the heavy lifting. 
#The code here finds the preferred name and ID number of each term under your
#chosen term. 
#It then looks to see if the child terms of your chosen term have any children. 
#If it does, it pulls out the name and ID of that term too. 
#The term names are all printed below.
#This is the part that does the heavy lifting. 
#The code here finds the preferred name and ID number of each term under your
#chosen term. 
#It then looks to see if the child terms of your chosen term have any children. 
#If it does, it pulls out the name and ID of that term too. 
#The term names are all printed below.
ids = []
terms = []
terms.append(termname)
bing = terminfo.split("/")[4]
ids.append(bing)
termjson = terminfo + '.json'
tj = requests.get(termjson)
j2 = json.loads(tj.text)
try:
    j3 = j2['result']['primaryTopic']['narrower']
    print(j3)
    for i in j3:
        try:
            termbits = (i['prefLabel']['_value'])
            terms.append(termbits)
        except TypeError:
            termbits = (j3['prefLabel']['_value'])
            terms.append(termbits)
        try:
            jsnoos = i['_about']
        except TypeError:
            jsnoos = j3['_about']  
        jbing = jsnoos.split("/")[4]
        ids.append(jbing)
        try:
            j4 = i['_about']
        except TypeError:
            j4 = j3['_about']
        j5 = j4 + '.json'
        j6 = requests.get(j5)
        j7 = json.loads(j6.text)
        try:
            j8 = j7['result']['primaryTopic']['narrower']
            for i in j8:
                try:
                    termbits1 = (i['prefLabel']['_value'])
                    terms.append(termbits1)
                except TypeError:
                    termbits1 = (j8['prefLabel']['_value'])
                    terms.append(termbits1)
                try:
                    ksnoos = i['_about']
                except TypeError:
                    ksnoos = j8['_about']  
                kbing = ksnoos.split("/")[4]
                ids.append(kbing)
                try:
                    k4 = i['_about']
                except TypeError:
                    k4 = j8['_about']
                k5 = k4 + '.json'
                k6 = requests.get(k5)
                k7 = json.loads(k6.text)
                try:
                    k8 = k7['result']['primaryTopic']['narrower']
                    for i in k8:
                        try:
                            termbits2 = (i['prefLabel']['_value'])
                            terms.append(termbits2)
                        except TypeError:
                            termbits2 = (k8['prefLabel']['_value'])
                            terms.append(termbits2)
                        try:
                            lsnoos = i['_about']
                        except TypeError:
                            lsnoos = k8['_about']  
                        lbing = lsnoos.split("/")[4]
                        ids.append(lbing)
                        try:
                            l4 = i['_about']
                        except TypeError:
                            l4 = k8['_about']
                        l5 = l4 + '.json'
                        l6 = requests.get(l5)
                        l7 = json.loads(l6.text)
                        try:
                            l8 = l7['result']['primaryTopic']['narrower']
                            for i in l8:
                                termbits3 = (l8['prefLabel']['_value'])
                                terms.append(termbits3)
                        except: "KeyError"
                        pass
                except: "KeyError"
                pass
        except: "KeyError"
        pass
except: "KeyError"
pass

# %%
#This part takes all of the IDs and puts them into a text string, with "OR" 
#in between each ID. This will output a text string that can be copied into 
#Parliamentary Search. 
#
#You can change the paramters of the search below, or change them in Search.

def remove_duplicates(values):
    output = []
    seen = set()
    for value in values:
        # If value has not been encountered yet,
        # ... add it to both list and set.
        if value not in seen:
            output.append(value)
            seen.add(value)
    return output

# Remove duplicates from this list.
result = remove_duplicates(ids)
termlist = remove_duplicates(terms)
print(termlist)
stringy = ' OR '.join(result)
if j['result']['items'][0]['class'] == "":
    if j['result']['items'][0]['attribute'] == "TPG":
        print('topic_ses:('+stringy+") session:17/19")
    else:
        print('subject_ses:('+stringy+") session:17/19")
elif j['result']['items'][0]['class'] == "TPG":
    print('topic_ses:('+stringy+") session:17/19")
else:
    print('subject_ses:('+stringy+") session:17/19")
# Out:
# ['Members of Parliament']
# topic_ses:(95674) session:17/19
